# %% [markdown]
# # Algorithms for Data Science

# %% [markdown]
# ## Computing Moments of a Stream

# %% [markdown]
# ### 1. Preliminaries
#
# The objective of this lab is to implement the Alon-Matias-Szegedy approach to estimate the second moment of the stream in which $N$ distinct items from $0$ to $N-1$ appear.

# %%
import random

#parameters
N = 256 #N distinct values between 0 and N-1
stream_size = 10000

# %% [markdown]
# ### 2. Alon-Matias-Szegedy for Second Moments
#
# We implement here the AMS approach when the stream size is known:
# 1. We choose a number $t$ between $0$ and $\text{stream\_size}-1$ from which the counts are kept
# 2. When the stream is at timestamp $t$, we initialize $\text{v}=S(t)$ and $c=1$
# 3. Whenever we encounter $v$ in the stream, we increment $c$ by $1$
#
# At the end of the stream, we output the estimator $\text{stream\_size}\times(2c-1)$
#
# This can be easily extended to an arbirary number of counts, by generating $k$ different timestamps and keeping arrays of $v$ and $c$.

# %%
#initialize values and counts
v = []
c = []
#keeping the true counts 
counts = {}
#choosing k timestamps
k = 10
t = []
for _ in range(k):
  t.append(random.randrange(stream_size))
  v.append(-1)
  c.append(0)

for i in range(stream_size):
  #take a random value between 0 and N-1
  s = random.randrange(N)
  #AMS approach
  for j in range(k):
    if i==t[j]: #chosen timestamp
      v[j] = s
      c[j] = 1
    elif i>t[j] and s==v[j]: #after timestamp
      c[j] += 1
  #true counts (only for evaluation!)
  if s not in counts:
    counts[s] = 0
  counts[s] = counts[s]+1

#true 2nd moment
true = 0
for x in counts.keys():
  true += counts[x]*counts[x]

#2nd moment estimator
est = 0
for x in range(k):
  est += 2*c[x]-1
est = int((stream_size/k)*est)

print('Estimation of 2nd moment: %d'%est)
print('True second moment: %d'%true)
# Out:
# Estimation of 2nd moment: 478000
# True second moment: 401936

# %% [markdown]
# ### 3. **TASK** AMS for Infinite Streams
#
# Implement the case when the estimator does not know the size of the stream.
#
# In this case, instead of generating $k$ timestamps, we proceed to use _Reservoir Sampling_ as explained in the lecture:
# 1. initialize $v$ and $c$ with the corresponding values in the first $k$ items in the stream $S$,
# 2. for timestamp $t>k$, we decide whether to replace a $v$ with probability $k/t$,
# 3. if true, we replace a value (and its corresponding count) at random in the arrays $v$ and $c$ (and re-initialize the values).

# %%
#Reservoir Sampling Implementation

v = []
k = 10

for i in range(100):
  s = random.randrange(N)
  #we want to keep a sample of the stream, of k values in the array v
  if i<k: #if the timestamp is between 0 and k-1
    print ('Timestamp %d<%d  value %d -- fill'%(i,k,s))
    v.append(s) #fill the reservoir
  else:
    #decide whether the new value replaces one of the old ones
    c = random.random() #chooses a value in [0,1] uniformly
    print ('Timestamp %d>=%d value %d -- decide whether to replace'%(i,k,s))
    if c <= k/i: #if c is between [0,k/i] then we want to replace, if c is in (k/i,1] we discard
      
      #we keep
      j = random.randrange(k) #choose a value between 0 and k-1 to replace
      print ('\t coin %f <= %f -- replace pos %d'%(c,k/i,j))
      v[j] = s #replace with the new value in the stream
    else:
      print ('\t coin %f > %f -- do not replace'%(c,k/i))
  print(v)
# Out:
# Timestamp 0<10  value 141 -- fill
# [141]
# Timestamp 1<10  value 26 -- fill
# [141, 26]
# Timestamp 2<10  value 171 -- fill
# [141, 26, 171]
# Timestamp 3<10  value 125 -- fill
# [141, 26, 171, 125]
# Timestamp 4<10  value 239 -- fill
# [141, 26, 171, 125, 239]
# Timestamp 5<10  value 20 -- fill
# [141, 26, 171, 125, 239, 20]
# Timestamp 6<10  value 219 -- fill
# [141, 26, 171, 125, 239, 20, 219]
# Timestamp 7<10  value 128 -- fill
# [141, 26, 171, 125, 239, 20, 219, 128]
# Timestamp 8<10  value 39 -- fill
# [141, 26, 171, 125, 239, 20, 219, 128, 39]
# Timestamp 9<10  value 148 -- fill
# [141, 26, 171, 125, 239, 20, 219, 128, 39, 148]
# Timestamp 10>=10 value 60 -- decide whether to replace
# 	 coin 0.625448 <= 1.000000 -- replace pos 6
# [141, 26, 171, 125, 239, 20, 60, 128, 39, 148]
# Timestamp 11>=10 value 107 -- decide whether to replace
# 	 coin 0.806861 <= 0.909091 -- replace pos 2
# [141, 26, 107, 125, 239, 20, 60, 128, 39, 148]
# Timestamp 12>=10 value 189 -- decide whether to replace
# 	 coin 0.219145 <= 0.833333 -- replace pos 1
# [141, 189, 107, 125, 239, 20, 60, 128, 39, 148]
# Timestamp 13>=10 value 214 -- decide whether to replace
# 	 coin 0.114644 <= 0.769231 -- replace pos 3
# [141, 189, 107, 214, 239, 20, 60, 128, 39, 148]
# Timestamp 14>=10 value 98 -- decide whether to replace
# 	 coin 0.433624 <= 0.714286 -- replace pos 1
# [141, 98, 107, 214, 239, 20, 60, 128, 39, 148]
# Timestamp 15>=10 value 73 -- decide whether to replace
# 	 coin 0.753689 > 0.666667 -- do not replace
# [141, 98, 107, 214, 239, 20, 60, 128, 39, 148]
# Timestamp 16>=10 value 69 -- decide whether to replace
# 	 coin 0.537240 <= 0.625000 -- replace pos 0
# [69, 98, 107, 214, 239, 20, 60, 128, 39, 148]
# Timestamp 17>=10 value 149 -- decide whether to replace
# 	 coin 0.537780 <= 0.588235 -- replace pos 4
# [69, 98, 107, 214, 149, 20, 60, 128, 39, 148]
# Timestamp 18>=10 value 92 -- decide whether to replace
# 	 coin 0.046234 <= 0.555556 -- replace pos 9
# [69, 98, 107, 214, 149, 20, 60, 128, 39, 92]
# Timestamp 19>=10 value 201 -- decide whether to replace
# 	 coin 0.086571 <= 0.526316 -- replace pos 0
# [201, 98, 107, 214, 149, 20, 60, 128, 39, 92]
# Timestamp 20>=10 value 202 -- decide whether to replace
# 	 coin 0.109825 <= 0.500000 -- replace pos 9
# [201, 98, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 21>=10 value 67 -- decide whether to replace
# 	 coin 0.876821 > 0.476190 -- do not replace
# [201, 98, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 22>=10 value 132 -- decide whether to replace
# 	 coin 0.130302 <= 0.454545 -- replace pos 1
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 23>=10 value 246 -- decide whether to replace
# 	 coin 0.617778 > 0.434783 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 24>=10 value 172 -- decide whether to replace
# 	 coin 0.465209 > 0.416667 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 25>=10 value 119 -- decide whether to replace
# 	 coin 0.570552 > 0.400000 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 26>=10 value 250 -- decide whether to replace
# 	 coin 0.893005 > 0.384615 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 27>=10 value 219 -- decide whether to replace
# 	 coin 0.780358 > 0.370370 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 39, 202]
# Timestamp 28>=10 value 68 -- decide whether to replace
# 	 coin 0.211985 <= 0.357143 -- replace pos 8
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 29>=10 value 30 -- decide whether to replace
# 	 coin 0.774502 > 0.344828 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 30>=10 value 107 -- decide whether to replace
# 	 coin 0.374149 > 0.333333 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 31>=10 value 23 -- decide whether to replace
# 	 coin 0.832692 > 0.322581 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 32>=10 value 126 -- decide whether to replace
# 	 coin 0.983449 > 0.312500 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 33>=10 value 139 -- decide whether to replace
# 	 coin 0.998610 > 0.303030 -- do not replace
# [201, 132, 107, 214, 149, 20, 60, 128, 68, 202]
# Timestamp 34>=10 value 68 -- decide whether to replace
# 	 coin 0.284917 <= 0.294118 -- replace pos 3
# [201, 132, 107, 68, 149, 20, 60, 128, 68, 202]
# Timestamp 35>=10 value 151 -- decide whether to replace
# 	 coin 0.609210 > 0.285714 -- do not replace
# [201, 132, 107, 68, 149, 20, 60, 128, 68, 202]
# Timestamp 36>=10 value 176 -- decide whether to replace
# 	 coin 0.702716 > 0.277778 -- do not replace
# [201, 132, 107, 68, 149, 20, 60, 128, 68, 202]
# Timestamp 37>=10 value 40 -- decide whether to replace
# 	 coin 0.204391 <= 0.270270 -- replace pos 7
# [201, 132, 107, 68, 149, 20, 60, 40, 68, 202]
# Timestamp 38>=10 value 84 -- decide whether to replace
# 	 coin 0.475309 > 0.263158 -- do not replace
# [201, 132, 107, 68, 149, 20, 60, 40, 68, 202]
# Timestamp 39>=10 value 46 -- decide whether to replace
# 	 coin 0.076654 <= 0.256410 -- replace pos 4
# [201, 132, 107, 68, 46, 20, 60, 40, 68, 202]
# Timestamp 40>=10 value 25 -- decide whether to replace
# 	 coin 0.434078 > 0.250000 -- do not replace
# [201, 132, 107, 68, 46, 20, 60, 40, 68, 202]
# Timestamp 41>=10 value 97 -- decide whether to replace
# 	 coin 0.182650 <= 0.243902 -- replace pos 4
# [201, 132, 107, 68, 97, 20, 60, 40, 68, 202]
# Timestamp 42>=10 value 137 -- decide whether to replace
# 	 coin 0.278836 > 0.238095 -- do not replace
# [201, 132, 107, 68, 97, 20, 60, 40, 68, 202]
# Timestamp 43>=10 value 237 -- decide whether to replace
# 	 coin 0.204315 <= 0.232558 -- replace pos 4
# [201, 132, 107, 68, 237, 20, 60, 40, 68, 202]
# Timestamp 44>=10 value 76 -- decide whether to replace
# 	 coin 0.096914 <= 0.227273 -- replace pos 3
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 45>=10 value 111 -- decide whether to replace
# 	 coin 0.714186 > 0.222222 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 46>=10 value 55 -- decide whether to replace
# 	 coin 0.846222 > 0.217391 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 47>=10 value 135 -- decide whether to replace
# 	 coin 0.726312 > 0.212766 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 48>=10 value 126 -- decide whether to replace
# 	 coin 0.974372 > 0.208333 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 49>=10 value 5 -- decide whether to replace
# 	 coin 0.229444 > 0.204082 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 50>=10 value 40 -- decide whether to replace
# 	 coin 0.408799 > 0.200000 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 51>=10 value 175 -- decide whether to replace
# 	 coin 0.370380 > 0.196078 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 52>=10 value 214 -- decide whether to replace
# 	 coin 0.462910 > 0.192308 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 53>=10 value 108 -- decide whether to replace
# 	 coin 0.794962 > 0.188679 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 54>=10 value 207 -- decide whether to replace
# 	 coin 0.895264 > 0.185185 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 55>=10 value 200 -- decide whether to replace
# 	 coin 0.360864 > 0.181818 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 56>=10 value 194 -- decide whether to replace
# 	 coin 0.744214 > 0.178571 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 57>=10 value 105 -- decide whether to replace
# 	 coin 0.745466 > 0.175439 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 58>=10 value 219 -- decide whether to replace
# 	 coin 0.938286 > 0.172414 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 59>=10 value 16 -- decide whether to replace
# 	 coin 0.802846 > 0.169492 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 60>=10 value 41 -- decide whether to replace
# 	 coin 0.448187 > 0.166667 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 61>=10 value 113 -- decide whether to replace
# 	 coin 0.929660 > 0.163934 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 62>=10 value 218 -- decide whether to replace
# 	 coin 0.755405 > 0.161290 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 63>=10 value 183 -- decide whether to replace
# 	 coin 0.958588 > 0.158730 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 64>=10 value 36 -- decide whether to replace
# 	 coin 0.993186 > 0.156250 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 65>=10 value 44 -- decide whether to replace
# 	 coin 0.993630 > 0.153846 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 68, 202]
# Timestamp 66>=10 value 117 -- decide whether to replace
# 	 coin 0.143066 <= 0.151515 -- replace pos 8
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 67>=10 value 65 -- decide whether to replace
# 	 coin 0.824209 > 0.149254 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 68>=10 value 74 -- decide whether to replace
# 	 coin 0.604857 > 0.147059 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 69>=10 value 215 -- decide whether to replace
# 	 coin 0.658561 > 0.144928 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 70>=10 value 112 -- decide whether to replace
# 	 coin 0.279604 > 0.142857 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 71>=10 value 5 -- decide whether to replace
# 	 coin 0.292200 > 0.140845 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 72>=10 value 216 -- decide whether to replace
# 	 coin 0.555565 > 0.138889 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 73>=10 value 182 -- decide whether to replace
# 	 coin 0.653060 > 0.136986 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 74>=10 value 34 -- decide whether to replace
# 	 coin 0.690573 > 0.135135 -- do not replace
# [201, 132, 107, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 75>=10 value 252 -- decide whether to replace
# 	 coin 0.053854 <= 0.133333 -- replace pos 2
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 76>=10 value 50 -- decide whether to replace
# 	 coin 0.411811 > 0.131579 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 77>=10 value 91 -- decide whether to replace
# 	 coin 0.767963 > 0.129870 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 78>=10 value 46 -- decide whether to replace
# 	 coin 0.650004 > 0.128205 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 79>=10 value 192 -- decide whether to replace
# 	 coin 0.648757 > 0.126582 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 80>=10 value 88 -- decide whether to replace
# 	 coin 0.503110 > 0.125000 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 81>=10 value 215 -- decide whether to replace
# 	 coin 0.191602 > 0.123457 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 82>=10 value 99 -- decide whether to replace
# 	 coin 0.634379 > 0.121951 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 83>=10 value 52 -- decide whether to replace
# 	 coin 0.831548 > 0.120482 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 84>=10 value 40 -- decide whether to replace
# 	 coin 0.441464 > 0.119048 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 85>=10 value 105 -- decide whether to replace
# 	 coin 0.311943 > 0.117647 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 86>=10 value 121 -- decide whether to replace
# 	 coin 0.783219 > 0.116279 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 87>=10 value 207 -- decide whether to replace
# 	 coin 0.227156 > 0.114943 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 88>=10 value 170 -- decide whether to replace
# 	 coin 0.891382 > 0.113636 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 89>=10 value 164 -- decide whether to replace
# 	 coin 0.132798 > 0.112360 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 90>=10 value 73 -- decide whether to replace
# 	 coin 0.767531 > 0.111111 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 40, 117, 202]
# Timestamp 91>=10 value 93 -- decide whether to replace
# 	 coin 0.027207 <= 0.109890 -- replace pos 7
# [201, 132, 252, 76, 237, 20, 60, 93, 117, 202]
# Timestamp 92>=10 value 73 -- decide whether to replace
# 	 coin 0.900504 > 0.108696 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 117, 202]
# Timestamp 93>=10 value 43 -- decide whether to replace
# 	 coin 0.610135 > 0.107527 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 117, 202]
# Timestamp 94>=10 value 108 -- decide whether to replace
# 	 coin 0.980279 > 0.106383 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 117, 202]
# Timestamp 95>=10 value 231 -- decide whether to replace
# 	 coin 0.946127 > 0.105263 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 117, 202]
# Timestamp 96>=10 value 163 -- decide whether to replace
# 	 coin 0.025721 <= 0.104167 -- replace pos 8
# [201, 132, 252, 76, 237, 20, 60, 93, 163, 202]
# Timestamp 97>=10 value 211 -- decide whether to replace
# 	 coin 0.612935 > 0.103093 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 163, 202]
# Timestamp 98>=10 value 44 -- decide whether to replace
# 	 coin 0.341382 > 0.102041 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 163, 202]
# Timestamp 99>=10 value 150 -- decide whether to replace
# 	 coin 0.826407 > 0.101010 -- do not replace
# [201, 132, 252, 76, 237, 20, 60, 93, 163, 202]

# %%
#initialize values and counts
v = []
c = []
#keeping the true counts 
counts = {}
#choosing k timestamps
k = 10
t = []
for _ in range(k):
  t.append(random.randrange(stream_size))
  v.append(-1)
  c.append(0)

for i in range(stream_size):
  #take a random value between 0 and N-1
  s = random.randrange(N)
  #AMS approach
  for j in range(k):
    if i==t[j]: #chosen timestamp
      v[j] = s
      c[j] = 1
    elif i>t[j] and s==v[j]: #after timestamp
      c[j] += 1
  #true counts (only for evaluation!)
  if s not in counts:
    counts[s] = 0
  counts[s] = counts[s]+1

#true 2nd moment
true = 0
for x in counts.keys():
  true += counts[x]*counts[x]

#2nd moment estimator
est = 0
for x in range(k):
  est += 2*c[x]-1
est = int((stream_size/k)*est)

print('Estimation of 2nd moment: %d'%est)
print('True second moment: %d'%true)

# %% [markdown]
# _You can use this cell to write your discussion of the results_
